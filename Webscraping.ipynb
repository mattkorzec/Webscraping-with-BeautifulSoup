# %% [markdown]
# ## Webscaping Ford Mustangs from Cars.com

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# There are 11 pages of mustangs on sale on Cars.com. This means we have to scrape all 11 pages. First, create a loop over all eleven pages and assign them to a list

# %%
pages = []

for i in range(1, 12):
    url = 'https://www.cars.com/for-sale/searchresults.action/?dealerType=all&mdId=21712&mkId=20015&page=' + str(i) + '&perPage=20&rd=30&searchSource=PAGINATION&sort=relevance&stkTypId=28881&zc=20814'
    pages.append(url)

# %%
# Let's check if it looks correctly

pages[:5]
# Out:
# ['https://www.cars.com/for-sale/searchresults.action/?dealerType=all&mdId=21712&mkId=20015&page=1&perPage=20&rd=30&searchSource=PAGINATION&sort=relevance&stkTypId=28881&zc=20814',
#  'https://www.cars.com/for-sale/searchresults.action/?dealerType=all&mdId=21712&mkId=20015&page=2&perPage=20&rd=30&searchSource=PAGINATION&sort=relevance&stkTypId=28881&zc=20814',
#  'https://www.cars.com/for-sale/searchresults.action/?dealerType=all&mdId=21712&mkId=20015&page=3&perPage=20&rd=30&searchSource=PAGINATION&sort=relevance&stkTypId=28881&zc=20814',
#  'https://www.cars.com/for-sale/searchresults.action/?dealerType=all&mdId=21712&mkId=20015&page=4&perPage=20&rd=30&searchSource=PAGINATION&sort=relevance&stkTypId=28881&zc=20814',
#  'https://www.cars.com/for-sale/searchresults.action/?dealerType=all&mdId=21712&mkId=20015&page=5&perPage=20&rd=30&searchSource=PAGINATION&sort=relevance&stkTypId=28881&zc=20814']

# %% [markdown]
# Now, make the html look nicer so we can extract the data easier

# %%
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser')

# Won't print entire html for the purpose of this notebook
# print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <meta content="app-id=353263352" name="apple-itunes-app"/>
#   <link href="/cldstatic/header/0.1.32/manifest.json" rel="manifest"/>
#   <link href="/cldstatic/header/0.1.32/header.component.css" rel="stylesheet">
#    <script defer="" src="/cldstatic/header/0.1.32/header.component.js">
#    </script>
#    <meta charset="utf-8"/>
#    <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#    <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/>
#    <title>
#     Cars.com
#    </title>
#    <meta content="noindex, follow" name="robots"/>
#    <meta content="telephone=no" name="format-detection"/>
#    <link href="/static/www/fb628e116171/manifest.json" rel="manifest"/>
#    <meta content="app-id=353263352" name="apple-itunes-app"/>
#    <link href="https://www.cstatic-images.com" rel="preconnect"/>
#    <link href="https://fonts.gstatic.com" rel="preconnect"/>
#    <link href="https://assets.adobedtm.com" rel="preconnect"/>
#    <link href="https://cdn.optimizely.com" rel="preconnect"/>
#    <link href="https://api.cars.com" rel="preconnect"/>
#    <link href="https://sb.scorecardresearch.com" rel="preconnect"/>
#    <link href="https://ad.doubleclick.net" rel="preconnect"/>
#    <link href="https://www.googletagservices.com" rel="preconnect"/>
#    <link href="https://pubads.g.doubleclick.net" rel="preconnect"/>
#    <link href="https://carscomconsumer.collect.igodigital.com" rel="preconnect"/>
#    <link href="https://ai.autoid.com" rel="preconnect"/>
#    <link href="https://api.autoid.com" rel="preconnect"/>
#    <meta content="290349283473" property="fb:app_id"/>
#    <meta content="Cars.com" property="og:site_name"/>
#    <meta content="website" property="og:type"/>
#    <meta content="https://graphics.cars.com/images/core/logo.png" property="og:image"/>
#    <meta content="@carsdotcom" name="twitter:site"/>
#    <meta content="https://graphics.cars.com/images/core/logo.png" name="twitter:image"/>
#    <meta content="summary" name="twitter:card"/>
#    <script>
#     window.CARS = window.CARS || {};
#     CARS.digitalData = {"page":{"pageInfo":{"pageName":"Used Cars/Search/Results-CAM-inventory","channel":"Used Cars/Search"},"category":{"type":"search-results"},"search":{"typeOfSearch":"inventory","make":"Ford","model":"Mustang","year":"All","stockType":"Used","certified":false,"bodyStyle":"All","trim":"All","zip":"20814","radius":30,"sortOrder":"searchRank1:DESC","numResultsReturned":309,"numResultsOnPage":20,"pageNum":11,"totalNumPages":16,"state":"","city":"Washingtondc","maxPrice":0,"minPrice":0,"searchTerms":"","searchId":"","filters":[{"name":"New/Used","value":[["Used"]]},{"name":"Make","value":[["Ford"]]},{"name":"Model","value":[["Mustang"]]}]},"vehicle":[{"type":"inventory","detail":"searchResults","listingId":774270841,"stockType":"Used","make":"Ford","makeId":20015,"model":"Mustang","modelId":21712,"year":2015,"trim":"V6","bodyStyle":"Coupe","customerId":199078,"seller":{"id":2446362,"name":"Audi Chantilly","phoneNumber":"8882491418","phoneNumber2":null,"distanceFromSearchZip":20,"customerId":199078,"sellerDisplayLabel":"Dealer","streetAddress":"14839 Stonecroft Center Ct","city":"Chantilly","state":"VA","truncatedDescription":"2015 FORD MUSTANG LOCAL TRADE REARVIEW CAMERA SATELLITE RADIO HANDSFRE...","rating":4.8,"reviewCount":"69","dealerChatProvider":"Dealer Inspire","hasCpoShowroomEnabled":false,"formattedPhoneNumber":"(888) 249-1418","formattedPhoneNumber2":null},"certified":false,"privateSeller":false,"price":15980,"mileage":45308,"vin":"1FA6P8AM6F5313545","priceBadge":"Good Deal"},{"type":"inventory","detail":"searchResults","listingId":755438168,"stockType":"Used","make":"Ford","makeId":20015,"model":"Mustang","modelId":21712,"year":2014,"trim":"GT","bodyStyle":"Coupe","customerId":192526,"seller":{"id":496404,"name":"Cherner Brothers Auto Brokers","phoneNumber":"3017614716","phoneNumber2":null,"distanceFromSearchZip":2,"customerId":192526,"sellerDisplayLabel":"Dealer","streetAddress":"10566 Metropolitan Ave","city":"Kensington","state":"MD","truncatedDescription":"Treat yourself with our 2014 Ford Mustang GT Coupe proudly displayed i...","rating":4.9,"reviewCount":"77","dealerChatProvider":null,"hasCpoShowroomEnabled":false,"formattedPhoneNumber":"(301) 761-4716","formattedPhoneNumber2":null},"certified":false,"privateSeller":false,"price":16999,"mileage":61536,"vin":"1ZVBP8CF7E5203445","priceBadge":"Great Deal"},{"type":"inventory","detail":"searchResults","listingId":775952399,"stockType":"Used","make":"Ford","makeId":20015,"model":"Mustang","modelId":21712,"year":2014,"trim":"GT Premium","bodyStyle":"Coupe","customerId":8476,"seller":{"id":430543,"name":"Koons Ford","phoneNumber":"4107093664","phoneNumber2":null,"distanceFromSearchZip":29,"customerId":8476,"sellerDisplayLabel":"Dealer","streetAddress":"6970 Security Blvd","city":"Windsor Mill","state":"MD","truncatedDescription":"Local Trade/ Premium/ 6-Speed Manual/ Reverse Sensing/GT Track Package...","rating":4.7,"reviewCount":"970","dealerChatProvider":"Dealer Inspire","hasCpoShowroomEnabled":true,"formattedPhoneNumber":"(410) 709-3664","formattedPhoneNumber2":null},"certified":false,"privateSeller":false,"price":23999,"mileage":22453,"vin":"1ZVBP8CF3E5228472","priceBadge":"Great Deal"},{"type":"inventory","detail":"searchResults","listingId":776203505,"stockType":"Used","make":"Ford","makeId":20015,"model":"Mustang","modelId":21712,"year":2016,"trim":"V6","bodyStyle":"Coupe","customerId":2208,"seller":{"id":435975,"name":"Academy Ford","phoneNumber":"8776940370","phoneNumber2":null,"distanceFromSearchZip":13,"customerId":2208,"sellerDisplayLabel":"Dealer","streetAddress":"13401 Baltimore Ave","city":"Laurel","state":"MD","truncatedDescription":"CARFAX One-Owner. Clean CARFAX. Deep Impact Blue Metallic 2016 Ford Mu...","rating":4.7,"reviewCount":"330","dealerChatProvider":null,"hasCpoShowroomEnabled":true,"formattedPhoneNumber":"(877) 694-0370","formattedPhoneNumber2":null},"certified":false,"privateSeller":false,"price":18989,"mileage":31596,"vi ...
#    </script>
#    <script>
#     window.tagSuppress = {};
#    </script>
#    <script>
#     window.callSourceData = {"user":{"city":null,"state":null,"pcid":null,"pdid":null,"score":6},"sellers":{"3017614716":496404,"3019459727":467378,"4107093664":430543,"4107931104":430562,"8882491418":2446362,"8776940370":435975,"8884785379":423694,"7039944636":1038706,"7034368107":23782156,"8553397493":437799,"5716421691":423971,"7033340375":435707,"7038328113":58285846,"5712979432":424056,"8778608722":8557093,"8778121393":426293,"8773007306":11065981},"sellersList":{"3017614716":{"id":496404,"phoneNumber":"3017614716"},"3019459727":{"id":467378,"phoneNumber":"3019459727"},"4107093664":{"id":430543,"phoneNumber":"4107093664"},"4107931104":{"id":430562,"phoneNumber":"4107931104"},"8882491418":{"id":2446362,"phoneNumber":"8882491418"},"8776940370":{"id":435975,"phoneNumber":"8776940370"},"8884785379":{"id":423694,"phoneNumber":"8884785379"},"7039944636":{"id":1038706,"phoneNumber":"7039944636"},"7034368107":{"id":23782156,"phoneNumber":"7034368107"},"8553397493":{"id":437799,"phoneNumber":"8553397493"},"5716421691":{"id":423971,"phoneNumber":"5716421691"},"7033340375":{"id":435707,"phoneNumber":"7033340375"},"7038328113":{"id":58285846,"phoneNumber":"7038328113"},"5712979432":{"id":424056,"phoneNumber":"5712979432"},"8778608722":{"id":8557093,"phoneNumber":"8778608722"},"8778121393":{"id":426293,"phoneNumber":"8778121393"},"8773007306":{"id":11065981,"phoneNumber":"8773007306"}},"dimensions":{"type":"Used","make":["Ford"],"model":["Mustang"],"trim":[],"bodyStyle":[],"extColor":[],"intColor":[],"year":[],"mlgId":[],"drvTrnId":[],"transTypeId":[],"cylCntId":[],"fuelTypeId":[],"drCntId":[],"normFeatureId":[],"autoPriceDealLabelId":[],"enhancedSpecialOffersId":[],"maxprice":null,"minprice":null,"zipcode":"20814","radius":30,"certified":false}};
#     window.callSourceFinished = function finished() {
#         document.querySelectorAll('.listing-row__phone').forEach(function(element){
#             element.classList.remove('obscure');
#         });
#     };
#     window.callSourceAnimationEnd = function animationEnd() {
#         var animationEvent = whichAnimationEvent(),
#         phoneMobile = document.querySelector('.listing-row__cta .listing-row__phone.obscure');
#         phoneDesktop = document.querySelector('.listing-row__dealer .listing-row__phone.obscure');
#
#         phoneMobile.addEventListener(animationEvent, animationEndCallback);
#         phoneDesktop.addEventListener(animationEvent, animationEndCallback);
#
#         function animationEndCallback(event) {
#             phoneMobile.removeEventListener(animationEvent, animationEndCallback);
#             phoneDesktop.removeEventListener(animationEvent, animationEndCallback);
#             console.log('DNI took too long, show default nubmers!');
#             window.callSourceFinished();
#         }
#
#         function whichAnimationEvent(){
#             var t,
#                 el = document.createElement("fakeelement");
#
#             var transitions = {
#                 "animation"      : "animationend",
#                 "OAnimation"     : "oAnimationEnd",
#                 "MozAnimation"   : "animationend",
#                 "WebkitAnimation": "webkitAnimationEnd"
#             };
#
#             for (t in transitions){
#                 if (el.style[t] !== undefined){
#                     return transitions[t];
#                 }
#             }
#         }
#     };
#    </script>
#    <script>
#     if (window.performance && performance.mark && performance.clearMarks) {
#         performance.clearMarks();
#         performance.mark('pageLoadStart');
#     }
#    </script>
#    <script>
#     window.carsStatic = "/static/www/fb628e116171";
#    </script>
#    <link href="/static/www/fb628e116171/srp.css" rel="stylesheet" type="text/css">
#     <script defer="" src="//cdn.optimizely.com/js/7544042.js">
#     </script>
#     <script type="text/javascript">
#      window.abon = true;
#     </script>
#     <script defer="" src="//assets.adobedtm.com/36e159fa28ebd11f42c753477615b777373ed969/satelliteLib-d02c51728c29ecf9a3db1b01abbed2ea57be2e3c.js">
#     </script>
#     <script async="" src="/static/www/fb628e116171/app/bundles/getad.js">
#     </script>
#     <link as="script" href="/static/www/fb628e116171/srp-module.js" rel="preload"/>
#     <script src="/static/www/fb628e116171/app/init-srp-module.js" type="module">
#     </script>
#     <script defer="" nomodule="" src="/static/www/fb628e116171/app/init-srp-nomodule.js">
#     </script>
#     <script type="text/javascript">
#     </script>
#     <script id="initial-data" type="application/json">
#      {"savedFeatureInstanceByListingId":{},"filters":{"allFilters":[{"key":"cpoId","name":"Certification","multiSelect":false,"values":[{"id":28444,"name":"Certified Used","count":14,"lowerBound":null,"upperBound":null}],"filterApplied":false},{"key":"yrId","name":"Year","multiSelect":true,"values":[{"id":20124,"name":"1966","count":1,"lowerBound":null,"upperBound":null},{"id":20193,"name":"1993","count":1,"lowerBound":null,"upperBound":null},{"id":20195,"name":"1997","count":1,"lowerBound":null,"upperBound":null},{"id":20140,"name":"1998","count":1,"lowerBound":null,"upperBound":null},{"id":20196,"name":"1999","count":1,"lowerBound":null,"upperBound":null},{"id":20141,"name":"2000","count":2,"lowerBound":null,"upperBound":null},{"id":20197,"name":"2001","count":2,"lowerBound":null,"upperBound":null},{"id":20198,"name":"2003","count":5,"lowerBound":null,"upperBound":null},{"id":20143,"name":"2004","count":2,"lowerBound":null,"upperBound":null},{"id":20199,"name":"2005","count":3,"lowerBound":null,"upperBound":null},{"id":20144,"name":"2006","count":4,"lowerBound":null,"upperBound":null},{"id":20200,"name":"2007","count":5,"lowerBound":null,"upperBound":null},{"id":20145,"name":"2008","count":5,"lowerBound":null,"upperBound":null},{"id":20201,"name":"2009","count":3,"lowerBound":null,"upperBound":null},{"id":27381,"name":"2010","count":8,"lowerBound":null,"upperBound":null},{"id":34923,"name":"2011","count":9,"lowerBound":null,"upperBound":null},{"id":39723,"name":"2012","count":7,"lowerBound":null,"upperBound":null},{"id":47272,"name":"2013","count":6,"lowerBound":null,"upperBound":null},{"id":51683,"name":"2014","count":19,"lowerBound":null,"upperBound":null},{"id":56007,"name":"2015","count":33,"lowerBound":null,"upperBound":null},{"id":58487,"name":"2016","count":38,"lowerBound":null,"upperBound":null},{"id":30031936,"name":"2017","count":37,"lowerBound":null,"upperBound":null},{"id":35797618,"name":"2018","count":100,"lowerBound":null,"upperBound":null},{"id":36362520,"name":"2019","count":16,"lowerBound":null,"upperBound":null}],"filterApplied":false},{"key":"mdId","name":"Model","multiSelect":true,"values":[{"id":20717,"name":"Bronco","count":2,"lowerBound":null,"upperBound":null},{"id":50243,"name":"C-Max Energi","count":25,"lowerBound":null,"upperBound":null},{"id":49085,"name":"C-Max Hybrid","count":17,"lowerBound":null,"upperBound":null},{"id":20906,"name":"Crown Victoria","count":1,"lowerBound":null,"upperBound":null},{"id":21050,"name":"E150","count":7,"lowerBound":null,"upperBound":null},{"id":26506,"name":"E250","count":18,"lowerBound":null,"upperBound":null},{"id":26502,"name":"E350","count":5,"lowerBound":null,"upperBound":null},{"id":26507,"name":"E350 Super Duty","count":16,"lowerBound":null,"upperBound":null},{"id":36284899,"name":"EcoSport","count":10,"lowerBound":null,"upperBound":null},{"id":21039,"name":"Edge","count":231,"lowerBound":null,"upperBound":null},{"id":21088,"name":"Escape","count":363,"lowerBound":null,"upperBound":null},{"id":21070,"name":"Escape Hybrid","count":3,"lowerBound":null,"upperBound":null},{"id":21102,"name":"Excursion","count":7,"lowerBound":null,"upperBound":null},{"id":21104,"name":"Expedition","count":77,"lowerBound":null,"upperBound":null},{"id":21085,"name":"Expedition EL","count":10,"lowerBound":null,"upperBound":null},{"id":36324071,"name":"Expedition Max","count":11,"lowerBound":null,"upperBound":null},{"id":21105,"name":"Explorer","count":390,"lowerBound":null,"upperBound":null},{"id":21107,"name":"Explorer Sport Trac","count":4,"lowerBound":null,"upperBound":null},{"id":21095,"name":"F-150","count":553,"lowerBound":null,"upperBound":null},{"id":21115,"name":"F-250","count":108,"lowerBound":null,"upperBound":null},{"id":21097,"name":"F-350","count":63,"lowerBound":null,"upperBound":null},{"id":21101,"name":"F-450","count":4,"lowerBound":null,"upperBound":null},{"id":21146,"name":"Fiesta","count":77,"lowerBound":null,"upperBound":null},{"id":21156,"name":"Five Hundred"," ...
#     </script>
#     <script>
#      (function(){
#                 var initialDataElement = document.getElementById('initial-data');
#
#                 window.initialData = JSON.parse(initialDataElement.textContent);
#
#                 if (initialDataElement.parentNode !== null) {
#                     initialDataElement.parentNode.removeChild(initialDataElement);
#                 }
#             }());
#     </script>
#     <script>
#      var w=window;if(w.performance||w.mozPerformance||w.msPerformance||w.webkitPerformance){var d=document;AKSB=w.AKSB||{},AKSB.q=AKSB.q||[],AKSB.mark=AKSB.mark||function(e,_){AKSB.q.push(["mark",e,_||(new Date).getTime()])},AKSB.measure=AKSB.measure||function(e,_,t){AKSB.q.push(["measure",e,_,t||(new Date).getTime()])},AKSB.done=AKSB.done||function(e){AKSB.q.push(["done",e])},AKSB.mark("firstbyte",(new Date).getTime()),AKSB.prof={custid:"411078",ustr:"",originlat:"0",clientrtt:"63",ghostip:"184.27.179.173",ipv6:false,pct:"10",clientip:"50.224.32.3",requestid:"68183a16",region:"17728",protocol:"",blver:14,akM:"e12",akN:"ae",akTT:"O",akTX:"1",akTI:"68183a16",ai:"271835",ra:"false",pmgn:"",pmgi:"",pmp:"",qc:""},function(e){var _=d.createElement("script");_.async="async",_.src=e;var t=d.getElementsByTagName("script"),t=t[t.length-1];t.parentNode.insertBefore(_,t)}(("https:"===d.location.protocol?"https:":"http:")+"//ds-aksb-a.akamaihd.net/aksb.min.js")}
#     </script>
#    </link>
#   </link>
#  </head>
#  <body class="">
#   <cars-dtm-init2>
#   </cars-dtm-init2>
#   <nav>
#    <cars-cobrand-bar>
#    </cars-cobrand-bar>
#    <header class="flat_w_profile" ng-non-bindable="">
#     <nav class="prof__nav not-logged-in">
#      <a data-linkname="header-home" href="/" target="_self">
#       <img alt="Cars.com" class="global-nav__logo" height="36" src="/cldstatic/header/0.1.32/logo.png" width="85"/>
#      </a>
#      <input id="prof__menu--trigger" style="display:none;" type="checkbox"/>
#      <input id="all__menu--trigger" style="display:none;" type="checkbox"/>
#      <label class="prof__overlay--mobile" for="all__menu--trigger" style="display: none;">
#      </label>
#      <label class="prof__overlay--desktop" for="prof__menu--trigger" style="display: none;">
#      </label>
#      <div class="prof__menu" style="display:none">
#       <div class="prof__menu__caret">
#        <label class="prof__menu__trigger" for="all__menu--trigger" style="display:none;">
#         <svg class="prof__menu--close" height="16px" width="16px">
#          <use xlink:href="/cldstatic/header/0.1.32/icons.svg#icon-close">
#          </use>
#         </svg>
#        </label>
#       </div>
#       <div class="prof__menu__greeting">
#        <p class="prof__menu__greeting--name hide-for-anonymous">
#         Hi,
#         <span class="prof__menu--name">
#          Guest
#         </span>
#         !
#        </p>
#        <p class="prof__menu__text hide-for-logged-in">
#         Save cars. Access them anywhere.
#         <a class="prof__menu__button js_continue" data-linkname="headerpro-sign-up" href="/profile/secure/signup/" target="_self">
#          Sign Up
#         </a>
#        </p>
#        <p class="prof__menu__text--small hide-for-logged-in">
#         Already have an account?
#         <a class="prof__menu__link js_continue" data-linkname="headerpro-sign-in" href="/profile/secure/login/" target="_self">
#          Log In
#         </a>
#        </p>
#       </div>
#       <div class="prof__menu--divider">
#        <a class="prof__link" data-linkname="headerpro-dashboard" href="/profile/dashboard/" id="prof_menu-dashboard" target="_self">
#         <svg class="prof__icon" height="16px" width="16px">
#          <use xlink:href="/cldstatic/header/0.1.32/icons.svg#icon-avatar-line">
#          </use>
#         </svg>
#         My Dashboard
#         <span class="prof__link--count">
#         </span>
#        </a>
#        <a class="prof__link hide-for-anonymous" data-linkname="headerpro-saved-research" href="/profile/saved-research/" id="prof_menu-savedresearch" target="_self">
#         <svg class="prof__icon" height="16px" width="16px">
#          <use xlink:href="/cldstatic/header/0.1.32/icons.svg#icon-features">
#          </use>
#         </svg>
#         My Saved Research
#         <span class="prof__link--count">
#          ( 0 )
#         </span>
#         <span class="prof__badge--new">
#          NEW
#         </span>
#        </a>
#        <a class="prof__link" data-linkname="headerpro-saved-cars" href="/profile/saved-cars/" id="prof_menu-savedcars" target="_self">
#         <svg class="prof__icon" height="16px" width="16px">
#          <use xlink:href="/cldstatic/header/0.1.32/icons.svg#icon-carfront-line">
#          </use>
#         </svg>
#         My Saved Cars
#         <span class="prof__link--count">
#          ( 0 )
#         </span>
#        </a>
#        <a class="prof__link" data-linkname="headerpro-saved-searches" href="/profile/saved-searches/" id="prof_menu-savedsearches" target="_self">
#         <svg class="prof__icon" height="16px" width="16px">
#          <use xlink:href="/cldstatic/header/0.1.32/icons.svg#icon-searchalt-line">
#          </use>
#         </svg>
#         My Saved Searches
#         <span class="prof__link--count">
#          ( 0 )
#         </span>
#        </a>
#        <a class="prof__link hide-for-anonymous" data-linkname="headerpro-ads" href="/sell/profile/" id="prof_menu-savedlistings" target="_self">
#         <svg class="prof__icon" height="16px" width="16px">
#          <use xlink:href="/cldstatic/header/0.1.32/icons.svg#icon-tag-line">
#          </use>
#         </svg>
#         My Listings
#         <span class="prof__link--count">
#          ( 0 )
#         </span>
#        </a>
#        <a class="prof__link hide-for-anonymous" data-linkname="headerpro-account-settings" href="/profile/secure/settings/" id="prof_menu-settings" target="_self">
#         <svg class="prof__icon" height="16px" width="16px">
#          <use xlink:href="/cldstatic/header/0.1.32/icons.svg#icon-settings-line">
#          </use>
#         </svg>
#         Settings
#         <span class="prof__link--count">
#         </span>
#        </a>
#       </div>
#       <ul class="prof__menu__global-nav__parent">
#        <li class="global-nav__container">
#         <a class="global-nav__link" data-linkname="header-buy" href="/shopping/" target="_self" title="Shop for new, used, and certified cars and trucks">
#          Cars for Sale
#         </a>
#        </li>
#        <li class="global-nav__container">
#         <a class="global-nav__link" data-linkname="header-sell" href="/sell/" target="_self" title="Sell your car online">
#          Sell Your Car
#         </a>
#        </li>
#        <li class="global-nav__container">
#         <a class="global-nav__link" data-linkname="header-service" href="/auto-repair/" target="_self" title="Estimates on car repairs or find a service shop near you">
#          Service &amp; Repair
#         </a>
#        </li>
#        <li class="global-nav__container">
#         <a class="global-nav__link" data-linkname="header-research" href="/research/" target="_self" title="Specifications and reviews on car models">
#          Research
#         </a>
#        </li>
#        <li class="global-nav__container">
#         <a class="global-nav__link" data-linkname="header-news" href="/news/" target="_self" title="Latest news and videos from the Cars.com editorial team">
#          Videos &amp; Reviews
#         </a>
#        </li>
#       </ul>
#       <div class="prof__menu__signout hide-for-anonymous">
#        <a class="prof__link" data-linkname="Log Out" href="/logout/" target="_self">
#         <b>
#          Sign Out
#         </b>
#        </a>
#       </div>
#       <div class="signal-link-container">
#       </div>
#      </div>
#      <ul class="global-nav__parent">
#       <li class="global-nav__container">
#        <a class="global-nav__link" data-linkname="header-buy" href="/shopping/" target="_self" title="Shop for new, used, and certified cars and trucks">
#         Cars for Sale
#        </a>
#       </li>
#       <li class="global-nav__container">
#        <a class="global-nav__link" data-linkname="header-sell" href="/sell/" target="_self" title="Sell your car online">
#         Sell Your Car
#        </a>
#       </li>
#       <li class="global-nav__container">
#        <a class="global-nav__link" data-linkname="header-service" href="/auto-repair/" target="_self" title="Estimates on car repairs or find a service shop near you">
#         Service &amp; Repair
#        </a>
#       </li>
#       <li class="global-nav__container">
#        <a class="global-nav__link" data-linkname="header-research" href="/research/" target="_self" title="Specifications and reviews on car models">
#         Research
#        </a>
#       </li>
#       <li class="global-nav__container">
#        <a class="global-nav__link" data-linkname="header-news" href="/news/" target="_self" title="Latest news and videos from the Cars.com editorial team">
#         Videos &amp; Reviews
#        </a>
#       </li>
#       <li class="global-nav__container--signup invisible-for-logged-in">
#        <a class="global-nav__link--signup js_continue" data-linkname="header-sign-up" href="/profile/secure/signup/" target="_self" title="login or signup">
#         Sign
#                 Up
#        </a>
#       </li>
#       <li class="global-nav__container">
#        <label class="prof__avatar--link" data-linkname="profiles-menu" for="prof__menu--trigger" id="profile_menu-avatar">
#         <svg class="prof__avatar--icon" height="24px" viewbox="0 0 16 16" width="24px">
#          <path d="M8,0C3.582,0,0,3.582,0,8c0,4.418,3.582,8,8,8c4.418,0,8-3.582,8-8C16,3.582,12.418,0,8,0z M8,0.735  c4.013,0,7.266,3.252,7.266,7.265c0,1.706-0.59,3.274-1.575,4.515c-0.301-0.455-0.784-0.887-1.507-1.16  c-0.897-0.341-2.558-1.075-2.633-1.49c-0.058-0.317,0.16-0.621,0.286-0.789c0.143-0.191,0.578-0.912,0.762-1.62  c0.123-0.473,0.681-2.897-0.377-4.208c-0.46-0.571-1.319-0.94-2.187-0.94c-0.893,0-1.801,0.379-2.261,0.944  c-1.16,1.431-0.522,3.995-0.468,4.232c0.167,0.731,0.677,1.44,0.734,1.551c0.116,0.225,0.37,0.41,0.313,0.83  c-0.02,0.149-0.612,0.722-2.625,1.483c-0.653,0.247-1.149,0.667-1.465,1.108C1.306,11.225,0.735,9.68,0.735,8  C0.735,3.987,3.987,0.735,8,0.735z M8,15.266c-2.097,0-3.986-0.891-5.312-2.312c0.447-0.578,0.906-0.852,1.74-1.188  c1.714-0.694,2.48-1.215,2.562-1.807C7.042,9.575,7,9.347,6.844,9.143C6.781,9.058,6.213,8.208,6.061,7.704  C5.898,7.164,5.347,5.184,6.163,3.837c0.312-0.515,1.071-0.878,1.82-0.878c0.762,0,1.383,0.326,1.742,0.816  c0.857,1.174,0.326,3.275,0.122,3.898c-0.161,0.493-0.738,1.38-0.796,1.468c-0.133,0.205-0.189,0.52-0.152,0.817  c0.081,0.663,1.611,1.398,2.448,1.755c0.744,0.317,1.488,0.599,1.889,1.32C11.914,14.409,10.058,15.266,8,15.266z">
#          </path>
#         </svg>
#        </label>
#       </li>
#       <li class="signal-link-container">
#       </li>
#      </ul>
#      <div class="mobile-nav__container">
#       <label class="menu__avatar--link" for="all__menu--trigger">
#        <svg class="menu__avatar--icon" height="16px" viewbox="0 0 16 16" width="16px">
#         <use xlink:href="/cldstatic/header/0.1.32/icons.svg#icon-menu-line">
#         </use>
#        </svg>
#       </label>
#      </div>
#     </nav>
#    </header>
#   </nav>
#   <div class="page">
#    <!-- FEO BARRIER -->
#    <cars-shop-srp-v2>
#    </cars-shop-srp-v2>
#    <div class="notification-area" id="notification-area" ng-non-bindable="">
#    </div>
#    <div class="cars-shop-srp-header-v2 srp-container" ng-non-bindable="">
#     <div class="breadcrumbsContainer">
#     </div>
#     <div class="header-primary__title-row">
#      <div>
#       <h1 class="srp-header">
#        Used Ford Mustang for Sale
#       </h1>
#      </div>
#     </div>
#    </div>
#    <div class="toolbar srp-container" ng-non-bindable="">
#     <div class="srp-default-toolbar">
#      <a class="new-search" data-customlink="click" data-linkname="new-search">
#       New Search
#      </a>
#      <a class="sort" data-customlink="click" data-linkname="sort-panel">
#       Sort
#      </a>
#      <a class="filter" data-customlink="click" data-linkname="gn-filter-menu">
#       Filter
#      </a>
#     </div>
#    </div>
#    <div class="cars-shop-srp-block">
#     <div class="header-primary__vehicle-match">
#     </div>
#     <cars-ad-ph class="ad_cont ad-srp_page-top" data-placement="14456078" data-size="page-top" data-slot="6427/buy.used/srp.top">
#     </cars-ad-ph>
#     <div class="srp-container">
#      <div class="listings-column">
#       <div class="listings-filters">
#        <div class="header-primary__title-row">
#         <div class="listings-filters_container">
#          <header class="filter-header">
#           <div class="matchcount">
#            <span class="filter-count">
#             309
#            </span>
#            <span class="filter-text">
#             matches near you
#            </span>
#            <div class="save-search">
#             <a cars-shop-srp-favorite-links-launcher="" data-customlink="click" data-linkname="save-search-gn">
#              <span class="matchcount-divider">
#               |
#              </span>
#              Save Search
#             </a>
#            </div>
#           </div>
#           <form class="sort-desktop" name="sortForm" novalidate="">
#            <label class="sortForm__label">
#             Sort by:
#            </label>
#            <div class="select">
#             <select class="select-sort-options">
#              <option data-customlink="option-select" data-linkname="sort-best-match" selected="" value="relevance">
#               Relevance: Best Match
#              </option>
#              <option data-linkname="sort-best-deal" value="best-deal">
#               Deal: Best Deal
#              </option>
#              <option data-linkname="sort-price-highest" value="price-highest">
#               Price: Highest
#              </option>
#              <option data-linkname="sort-price-lowest" value="price-lowest">
#               Price: Lowest
#              </option>
#              <option data-linkname="sort-miles-lowest" value="miles-lowest">
#               Mileage: Lowest
#              </option>
#              <option data-linkname="sort-miles-highest" value="miles-highest">
#               Mileage: Highest
#              </option>
#              <option data-linkname="sort-newest" value="year-newest">
#               Year: Newest
#              </option>
#              <option data-linkname="sort-oldest" value="year-oldest">
#               Year: Oldest
#              </option>
#              <option data-linkname="sort-distance-nearest" value="distance-nearest">
#               Distance: Nearest
#              </option>
#              <option data-linkname="sort-photos-most" value="photos-most">
#               Photos: Most
#              </option>
#              <option data-linkname="sort-alphabetical" value="mm-alpha">
#               Make/Model: A to Z
#              </option>
#              <option data-linkname="sort-date-newest" value="listed-newest">
#               Date Listed: Newest
#              </option>
#             </select>
#             <div class="select__chevron">
#              <div class="cui-icon">
#               <svg class="icon-image select__chevron-gray" height="16" width="16">
#                <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#chevron">
#                </use>
#               </svg>
#              </div>
#             </div>
#            </div>
#           </form>
#          </header>
#          <div class="listings-filters_breadcrumb__container">
#           <div class="breadcrumb__top">
#            <p class="breadcrumb__filter-by">
#             Filtering by:
#            </p>
#            <span class="breadcrumb mobile clear-all" data-linkname="gn-bc-remove">
#             <label>
#              Clear All
#             </label>
#            </span>
#           </div>
#           <ul class="breadcrumbs">
#            <li class="breadcrumb desktop clear-all" data-linkname="gn-bc-remove">
#             <div class="cui-icon">
#              <svg class="remove-breadcrumb icon-image">
#               <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#close">
#               </use>
#              </svg>
#             </div>
#             <label>
#              Clear All
#             </label>
#            </li>
#            <li class="breadcrumb facet" data-dimension-id="mkId" data-dtm='{"name":"Make","value":"Ford"}' data-linkname="gn-bc-remove" data-value="20015">
#             <div class="cui-icon">
#              <svg class="remove-breadcrumb icon-image">
#               <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#close">
#               </use>
#              </svg>
#             </div>
#             <label>
#              Ford
#             </label>
#            </li>
#            <li class="breadcrumb facet" data-dimension-id="mdId" data-dtm='{"name":"Model","value":"Mustang"}' data-linkname="gn-bc-remove" data-value="21712">
#             <div class="cui-icon">
#              <svg class="remove-breadcrumb icon-image">
#               <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#close">
#               </use>
#              </svg>
#             </div>
#             <label>
#              Mustang
#             </label>
#            </li>
#            <li class="breadcrumb facet" data-dimension-id="stkTypId" data-dtm='{"name":"New/Used","value":"Used"}' data-linkname="gn-bc-remove" data-value="28881">
#             <div class="cui-icon">
#              <svg class="remove-breadcrumb icon-image">
#               <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#close">
#               </use>
#              </svg>
#             </div>
#             <label>
#              Used
#             </label>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#       <cars-save-search-alert passed-url="?zc=20814&amp;rd=30&amp;mkId=20015&amp;mdId=21712&amp;stkTypId=28881&amp;dealerType=all" style="background-image: url('/static/www/fb628e116171/app/images/wheel-image.jpg')">
#        <div class="save-search-alert__desktop desktop-single-ad-top" ng-if="!ctrl.formSubmitted">
#         <div class="save-search-alert__center">
#          <div class="save-search-alert__callout">
#           Get the latest listings by email
#          </div>
#          <form cars-email-capturer="" class="save-search-alert__form" email-capturer-email-selector=".save-search-alert__email-input" email-capturer-opt-in-required="true" email-capturer-submit-event-name="srpSearchAlertSuccess" ng-submit="ctrl.submitAlertForm()">
#           <input class="save-search-alert__email-input" ng-model="ctrl.email" ng-pattern="ctrl.emailFormat" placeholder="Email" required="" type="email"/>
#           <button class="save-search-alert__subscribe-btn" data-customlink="click" data-linkname="create-alert-search" ng-cloak="" ng-disabled="ctrl.isSaving">
#            {{ctrl.buttonText}}
#           </button>
#          </form>
#         </div>
#        </div>
#        <div class="save-search-alert__success" ng-cloak="" ng-if="ctrl.formSubmitted">
#         <svg>
#          <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#check-circle">
#          </use>
#         </svg>
#         <div>
#          <h3>
#           You have created an alert for this search
#          </h3>
#          <p>
#           When a new relevant car is added to our site, we will email you!
#          </p>
#         </div>
#        </div>
#       </cars-save-search-alert>
#       <div class="premier-srp" ng-attr-no-premier="{{(!displayPremier)}}" ng-attr-premier-type="{{(premierAd &amp;&amp; premierAd.pencil) ? 'pencil' : 'full'}}" ng-controller="premierController as premCtrl" no-premier="true" premier-type="full">
#        <div class="premier-ad-content" ng-if="premierAd">
#         <div class="premier-module-container" ng-attr-premier-type="{{premierAd.pencil ? 'pencil' : 'full'}}" premier-type="full">
#          <div class="dealer-details">
#           <div class="dealer-info">
#            <div class="dealer-logo">
#             <a data-linkname="dealer-logo-premier" href="" ng-click="premCtrl.alsClickthru('dealerProfilePage')" ng-href="{{premierAd.dealer.profileUrl}}" target="_self">
#              <img alt="" ng-attr-alt="{{premierAd.dealer.name}}" ng-show="premierAd.dealer.logo" ng-src="{{premierAd.dealer.logo}}" src=""/>
#             </a>
#            </div>
#            <div class="dealer-text">
#             <a class="premier-ad-dpp-link" data-linkname="dealer-name-premier" href="" ng-click="premCtrl.alsClickthru('dealerProfilePage')" ng-href="{{premierAd.dealer.profileUrl}}" target="_self">
#              <span class="dealer-name" ng-bind="premierAd.dealer.name">
#              </span>
#             </a>
#             <a class="premier-reviews-link" data-linkname="read-all-reviews-premier" href="#Reviews" ng-click="premCtrl.alsClickthru('dealerProfilePage')" ng-href="{{premierAd.dealer.profileUrl}}#Reviews" target="_self">
#              <div class="dealer-rating">
#               <span class="dealer-stars">
#                <svg class="premier-star" fill="empty" height="16" ng-attr-fill="{{premCtrl.getStarClass(1, premierAd.dealer.rating)}}" width="16">
#                 <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#star">
#                 </use>
#                </svg>
#                <svg class="premier-star" fill="empty" height="16" ng-attr-fill="{{premCtrl.getStarClass(2, premierAd.dealer.rating)}}" width="16">
#                 <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#star">
#                 </use>
#                </svg>
#                <svg class="premier-star" fill="empty" height="16" ng-attr-fill="{{premCtrl.getStarClass(3, premierAd.dealer.rating)}}" width="16">
#                 <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#star">
#                 </use>
#                </svg>
#                <svg class="premier-star" fill="empty" height="16" ng-attr-fill="{{premCtrl.getStarClass(4, premierAd.dealer.rating)}}" width="16">
#                 <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#star">
#                 </use>
#                </svg>
#                <svg class="premier-star" fill="empty" height="16" ng-attr-fill="{{premCtrl.getStarClass(5, premierAd.dealer.rating)}}" width="16">
#                 <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#star">
#                 </use>
#                </svg>
#               </span>
#               <span class="dealer-rating-info" ng-bind="premCtrl.getRatingString()">
#               </span>
#              </div>
#             </a>
#             <div class="dealer-phone" ng-if="premierAd.normalizedPhone">
#              <a ng-bind="premierAd.formattedPhone" ng-href="tel:{{premierAd.normalizedPhone}}">
#              </a>
#              <div ng-bind="premierAd.formattedPhone">
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="dealer-inventory" cloaked="true" ng-attr-cloaked="{{(!premierAd.inventoryLinks.showInventoryCounts)}}">
#            <span class="dealer-inventory-description">
#             Currently in stock:
#            </span>
#            <span class="dealer-inventory-summary">
#             <span class="dealer-inventory-count new" cloaked="true" ng-attr-cloaked="{{(!premierAd.inventoryLinks.new)}}" ng-if="premierAd.inventoryLinks.new">
#              <a data-linkname="new-inventory-premier" ng-click="premCtrl.alsClickthru('dealerSearchBuy')" ng-href="{{premierAd.inventoryLinks.new}}" target="_self">
#               <span ng-bind="{{premierAd.newInventory.count}}">
#               </span>
#               New
#              </a>
#             </span>
#             <span class="dealer-inventory-count cpo" cloaked="true" ng-attr-cloaked="{{(!premierAd.inventoryLinks.certified)}}" ng-if="premierAd.inventoryLinks.certified">
#              <a data-linkname="cpo-inventory-premier" ng-click="premCtrl.alsClickthru('dealerSearchBuy')" ng-href="{{premierAd.inventoryLinks.certified}}" target="_self">
#               <span ng-bind="{{premierAd.certifiedInventory.count}}">
#               </span>
#               CPO
#              </a>
#             </span>
#             <span class="dealer-inventory-count used" cloaked="true" ng-attr-cloaked="{{(!premierAd.inventoryLinks.used)}}" ng-if="premierAd.inventoryLinks.used">
#              <a data-linkname="used-inventory-premier" ng-click="premCtrl.alsClickthru('dealerSearchBuy')" ng-href="{{premierAd.inventoryLinks.used}}" target="_self">
#               <span ng-bind="{{premierAd.usedInventory.count}}">
#               </span>
#               Used
#              </a>
#             </span>
#            </span>
#           </div>
#          </div>
#          <div class="featured-vehicles" ng-if="!premierAd.pencil">
#           <div class="cui-carousel" left-scroll-dtm-name="carousel-previous-premier" ng-attr-loaded="{{true}}" right-scroll-dtm-name="carousel-next-premier">
#            <div class="car-wrapper" cloaked="true" ng-attr-cloaked="{{false}}" ng-if="premierAd.featured.first">
#             <div class="car">
#              <div badge="" class="deal-badge" ng-attr-badge="{{premierAd.featured.first.badge}}">
#               <div class="cui-icon arrow">
#                <svg height="16" width="16">
#                 <use ng-href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#arrow-chunky" xlink:href="">
#                 </use>
#                </svg>
#               </div>
#               <div class="cui-icon flame">
#                <svg height="16" width="16">
#                 <use ng-href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#flame-solid" xlink:href="">
#                 </use>
#                </svg>
#               </div>
#               <span>
#                <strong>
#                 GREAT
#                </strong>
#                DEAL
#               </span>
#               <span>
#                <strong>
#                 GOOD
#                </strong>
#                DEAL
#               </span>
#               <span>
#                <strong>
#                 HOT CAR
#                </strong>
#               </span>
#               <span>
#                PRICE DROP
#               </span>
#               <span>
#                JUST ADDED
#               </span>
#               <span>
#                <strong>
#                 FAIR
#                </strong>
#                PRICE
#               </span>
#              </div>
#              <figure>
#               <a data-linkname="photo-1-premier" ng-click="premCtrl.alsClickthru('vdp', 0)" ng-href="/vehicledetail/detail/{{premierAd.featured.first.vehicle.id}}/overview" rel="nofollow" target="_self">
#                <img class="image-link" ng-attr-alt="{{premierAd.featured.first.ymmt}}" ng-src="{{premierAd.featured.first.vehicle.thumbnailUrl}}"/>
#               </a>
#              </figure>
#              <div class="mmyt">
#               <a class="mmyt-link" data-linkname="text-1-premier" ng-bind="premierAd.featured.first.ymmt" ng-click="premCtrl.alsClickthru('vdp', 0)" ng-href="/vehicledetail/detail/{{premierAd.featured.first.vehicle.id}}/overview" rel="nofollow" target="_self">
#               </a>
#              </div>
#              <a class="car-details" data-linkname="text-1-premier" ng-click="premCtrl.alsClickthru('vdp', 0)" ng-href="/vehicledetail/detail/{{premierAd.featured.first.vehicle.id}}/overview" rel="nofollow" target="_self">
#               <span class="price" ng-bind="premierAd.featured.first.formattedPrice">
#               </span>
#               <span class="msrp" ng-bind="premierAd.featured.first.formattedMsrp" ng-if="premierAd.featured.first.formattedMsrp">
#               </span>
#               <span class="mileage" ng-bind="premierAd.featured.first.formattedMileage" ng-if="premierAd.featured.first.formattedMileage">
#               </span>
#              </a>
#             </div>
#            </div>
#            <div class="car-wrapper" cloaked="true" ng-attr-cloaked="{{false}}" ng-if="premierAd.featured.second">
#             <div class="car">
#              <div badge="" class="deal-badge" ng-attr-badge="{{premierAd.featured.second.badge}}">
#               <div class="cui-icon arrow">
#                <svg height="16" width="16">
#                 <use ng-href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#arrow-chunky" xlink:href="">
#                 </use>
#                </svg>
#               </div>
#               <div class="cui-icon flame">
#                <svg height="16" width="16">
#                 <use ng-href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#flame-solid" xlink:href="">
#                 </use>
#                </svg>
#               </div>
#               <span>
#                <strong>
#                 GREAT
#                </strong>
#                DEAL
#               </span>
#               <span>
#                <strong>
#                 GOOD
#                </strong>
#                DEAL
#               </span>
#               <span>
#                <strong>
#                 HOT CAR
#                </strong>
#               </span>
#               <span>
#                PRICE DROP
#               </span>
#               <span>
#                JUST ADDED
#               </span>
#               <span>
#                <strong>
#                 FAIR
#                </strong>
#                PRICE
#               </span>
#              </div>
#              <figure>
#               <a data-linkname="photo-2-premier" ng-click="premCtrl.alsClickthru('vdp', 1)" ng-href="/vehicledetail/detail/{{premierAd.featured.second.vehicle.id}}/overview" rel="nofollow" target="_self">
#                <img class="image-link" ng-attr-alt="{{premierAd.featured.second.ymmt}}" ng-src="{{premierAd.featured.second.vehicle.thumbnailUrl}}"/>
#               </a>
#              </figure>
#              <div class="mmyt">
#               <a class="mmyt-link" data-linkname="text-2-premier" ng-bind="premierAd.featured.second.ymmt" ng-click="premCtrl.alsClickthru('vdp', 1)" ng-href="/vehicledetail/detail/{{premierAd.featured.second.vehicle.id}}/overview" rel="nofollow" target="_self">
#               </a>
#              </div>
#              <a class="car-details" data-linkname="text-2-premier" ng-click="premCtrl.alsClickthru('vdp', 1)" ng-href="/vehicledetail/detail/{{premierAd.featured.second.vehicle.id}}/overview" rel="nofollow" target="_self">
#               <span class="price" ng-bind="premierAd.featured.second.formattedPrice">
#               </span>
#               <span class="msrp" ng-bind="premierAd.featured.second.formattedMsrp" ng-if="premierAd.featured.second.formattedMsrp">
#               </span>
#               <span class="mileage" ng-bind="premierAd.featured.second.formattedMileage" ng-if="premierAd.featured.second.formattedMileage">
#               </span>
#              </a>
#             </div>
#            </div>
#            <div class="car-wrapper" cloaked="true" ng-attr-cloaked="{{false}}" ng-if="premierAd.featured.third">
#             <div class="car">
#              <div badge="" class="deal-badge" ng-attr-badge="{{premierAd.featured.third.badge}}">
#               <div class="cui-icon arrow">
#                <svg height="16" width="16">
#                 <use ng-href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#arrow-chunky" xlink:href="">
#                 </use>
#                </svg>
#               </div>
#               <div class="cui-icon flame">
#                <svg height="16" width="16">
#                 <use ng-href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#flame-solid" xlink:href="">
#                 </use>
#                </svg>
#               </div>
#               <span>
#                <strong>
#                 GREAT
#                </strong>
#                DEAL
#               </span>
#               <span>
#                <strong>
#                 GOOD
#                </strong>
#                DEAL
#               </span>
#               <span>
#                <strong>
#                 HOT CAR
#                </strong>
#               </span>
#               <span>
#                PRICE DROP
#               </span>
#               <span>
#                JUST ADDED
#               </span>
#               <span>
#                <strong>
#                 FAIR
#                </strong>
#                PRICE
#               </span>
#              </div>
#              <figure>
#               <a data-linkname="photo-3-premier" ng-click="premCtrl.alsClickthru('vdp', 2)" ng-href="/vehicledetail/detail/{{premierAd.featured.third.vehicle.id}}/overview" rel="nofollow" target="_self">
#                <img class="image-link" ng-attr-alt="{{premierAd.featured.third.ymmt}}" ng-src="{{premierAd.featured.third.vehicle.thumbnailUrl}}"/>
#               </a>
#              </figure>
#              <div class="mmyt">
#               <a class="mmyt-link" data-linkname="text-3-premier" ng-bind="premierAd.featured.third.ymmt" ng-click="premCtrl.alsClickthru('vdp', 2)" ng-href="/vehicledetail/detail/{{premierAd.featured.third.vehicle.id}}/overview" rel="nofollow" target="_self">
#               </a>
#              </div>
#              <a class="car-details" data-linkname="text-3-premier" ng-click="premCtrl.alsClickthru('vdp', 2)" ng-href="/vehicledetail/detail/{{premierAd.featured.third.vehicle.id}}/overview" rel="nofollow" target="_self">
#               <span class="price" ng-bind="premierAd.featured.third.formattedPrice">
#               </span>
#               <span class="msrp" ng-bind="premierAd.featured.third.formattedMsrp" ng-if="premierAd.featured.third.formattedMsrp">
#               </span>
#               <span class="mileage" ng-bind="premierAd.featured.third.formattedMileage" ng-if="premierAd.featured.third.formattedMileage">
#               </span>
#              </a>
#             </div>
#            </div>
#            <div class="car-wrapper see-all-link">
#             <p>
# ...
#     </use>
#    </svg>
#   </div>
#  </div>
#  <ul class="refinements">
#   <li class="radio fulllist">
#    <input class="radio__input" data-customlink="gn-apply" data-dtm='{ "name" :"slrTypeId" ,"value": "Dealership" }' data-linkname="gn-ref-apply" id="slrTypeId-28878" name="slrTypeId" type="radio" value="28878"/>
#    <label class="radio__label" for="slrTypeId-28878">
#     Dealership
#     <span class="value-count">
#      (193)
#     </span>
#    </label>
#   </li>
#   <li class="radio fulllist">
#    <input class="radio__input" data-customlink="gn-apply" data-dtm='{ "name" :"slrTypeId" ,"value": "Private Party + Classified" }' data-linkname="gn-ref-apply" id="slrTypeId-28879" name="slrTypeId" type="radio" value="28879"/>
#    <label class="radio__label" for="slrTypeId-28879">
#     Private Party + Classified
#     <span class="value-count">
#      (15)
#     </span>
#    </label>
#   </li>
#  </ul>
# </li>
# <li class="dimension keywords" id="keywords">
#  <header class="dimension-header">
#   <div class="dimension-cta">
#    <span class="close cui-icon">
#     Back
#    </span>
#    <div class="title">
#     Keywords
#    </div>
#    <button class="apply-button">
#     Apply
#    </button>
#   </div>
#  </header>
#  <div class="dimension-toggler" data-customlink="click" data-dtm='{ "name" :"", "value": "Keywords" }' data-linkname="gn-ref-dimension">
#   <label>
#    Keywords
#   </label>
#   <div class="cui-icon chevron">
#    <svg class="icon-image">
#     <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#chevron">
#     </use>
#    </svg>
#   </div>
#  </div>
#  <ul class="refinements">
#   <li>
#    <input name="kw" placeholder="Keywords" type="text" value=""/>
#    <div class="select">
#     <select data-customlink="gn-apply" data-dtm='{ "name" :"kwm" ,"value": "Keyword Match" }' data-linkname="gn-ref-apply" name="kwm">
#      <option data-dtm='{"year" : "Match Any"}' name="kwm" value="ANY">
#       Match Any
#      </option>
#      <option data-dtm='{"year" : "Match All"}' name="kwm" value="ALL">
#       Match All
#      </option>
#      <option data-dtm='{"year" : "Match Exact"}' name="kwm" value="EXACT">
#       Match Exact
#      </option>
#     </select>
#     <div class="select__chevron">
#      <div class="cui-icon">
#       <svg class="icon-image select__chevron-gray" height="16" width="16">
#        <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#chevron">
#        </use>
#       </svg>
#      </div>
#     </div>
#    </div>
#    <button class="cui-button secondary">
#     Select
#    </button>
#   </li>
#  </ul>
# </li>
# <noscript>
#  <button type="submit">
#   Search
#  </button>
#  <style type="text/css">
#   .dimension .refinements{display:block;}
#  </style>
# </noscript>
# <div class="save-search__mobile">
#  <div class="save-search__mobile-button">
#   <button cars-shop-srp-favorite-links-launcher="">
#    Save This Search
#   </button>
#  </div>
# </div>
# <input id="newSearch" name="filter-tab" type="radio" value="newSearch"/>
# <label class="tab" data-customlink="click" data-linkname="gn-new-search-select" for="newSearch">
#  New Search
# </label>
# <new-search-form ng-non-bindable="">
#  <form>
#   <div class="legend">
#    New Search
#    <button class="close">
#     Close
#    </button>
#   </div>
#   <fieldset>
#    <div class="select">
#     <select aria-label="Select a stock type" name="stkTypId">
#      <option selected="" value="any">
#       New &amp; Used Cars
#      </option>
#      <option value="28880">
#       New Cars
#      </option>
#      <option value="28881">
#       Used Cars
#      </option>
#      <option value="28444">
#       Certified Cars
#      </option>
#     </select>
#    </div>
#    <div class="select">
#     <select name="mkId">
#      <option value="">
#       All Makes
#      </option>
#     </select>
#    </div>
#    <div class="select">
#     <select class="select" name="mdId">
#      <option value="">
#       All Models
#      </option>
#     </select>
#    </div>
#    <div class="select">
#     <select name="prMx">
#      <option selected="" value="">
#       No Max Price
#      </option>
#      <option value="2000">
#       $2,000
#      </option>
#      <option value="4000">
#       $4,000
#      </option>
#      <option value="6000">
#       $6,000
#      </option>
#      <option value="8000">
#       $8,000
#      </option>
#      <option value="10000">
#       $10,000
#      </option>
#      <option value="15000">
#       $15,000
#      </option>
#      <option value="20000">
#       $20,000
#      </option>
#      <option value="25000">
#       $25,000
#      </option>
#      <option value="30000">
#       $30,000
#      </option>
#      <option value="35000">
#       $35,000
#      </option>
#      <option value="40000">
#       $40,000
#      </option>
#      <option value="45000">
#       $45,000
#      </option>
#      <option value="50000">
#       $50,000
#      </option>
#      <option value="60000">
#       $60,000
#      </option>
#      <option value="70000">
#       $70,000
#      </option>
#      <option value="80000">
#       $80,000
#      </option>
#      <option value="90000">
#       $90,000
#      </option>
#      <option value="100000">
#       $100,000
#      </option>
#      <option value="125000">
#       $125,000
#      </option>
#      <option value="150000">
#       $150,000
#      </option>
#      <option value="175000">
#       $175,000
#      </option>
#     </select>
#    </div>
#   </fieldset>
#   <input data-linkname="gn-new-search-go" type="submit" value="Search"/>
#  </form>
# </new-search-form>
# <cars-ad-ph class="ad_cont ad-srp_gn-bottom--desktop" data-placement="14588284" data-size="guided-nav-bottom" data-slot="6427/buy.used/srp.gn">
# </cars-ad-ph>
# <save-stored-vehicle-via-forced-login>
# </save-stored-vehicle-via-forced-login>
# <cars-shop-srp-sort-panel panel-id="sortPanel" panel-title="Sort">
# </cars-shop-srp-sort-panel>
# <cars-modal-beta name="saveSearchModal" set-content-max-height="false">
#  <cars-shop-srp-favorite-links-form>
#  </cars-shop-srp-favorite-links-form>
# </cars-modal-beta>
# <cars-shop-shared-save-vehicle-modal>
# </cars-shop-shared-save-vehicle-modal>
# <cars-modal-beta is-small="true" name="favorite-limit-reached">
#  <cars-shop-shared-favorite-limit>
#  </cars-shop-shared-favorite-limit>
# </cars-modal-beta>
# <cars-special-events-ad-v2>
# </cars-special-events-ad-v2>
# <div class="native-ad-container">
# </div>
# <cars-shop-srp-compare-tray>
# </cars-shop-srp-compare-tray>
# <shop-lead-form-modal-native-wrapper apigee-host="https://api.cars.com" apigee-outbound-host="http://outbound-api-prod.cars.com" conversations-host="https://prod.api.conversations.dealerinspire.com" dealer-inspire-api-key="491NESWmW9LFVNV3gFmTdUvLFc2gPvUF" dipk="55ad0af85c1648a95fa6" embedded-chat-api="https://prod.api.conversations.dealerinspire.com" event-page-name="srp" has-dealer-from-texas="false" omniture-page-name="Cars/Search/details-details-dealer" search-alerts-url="?zc=20814&amp;rd=30&amp;mkId=20015&amp;mdId=21712&amp;stkTypId=28881&amp;dealerType=all" srp-api-key="Fi1DINVeB0SQhnD1FvtAfUX0KuwHF8Al">
# </shop-lead-form-modal-native-wrapper>
# <cars-typ-modal listing-id="{{ leadFormService.getListingId() }}">
# </cars-typ-modal>
# <cars-post-lead-survey apigee-host="https://api.cars.com" shadow-settings-proxy="/consumer-shadow-settings/" srp-api-key="Fi1DINVeB0SQhnD1FvtAfUX0KuwHF8Al">
# </cars-post-lead-survey>
# <phone-number-recovery-modal apigee-host="https://api.cars.com" shadow-settings-proxy="/consumer-shadow-settings/" srp-api-key="Fi1DINVeB0SQhnD1FvtAfUX0KuwHF8Al">
# </phone-number-recovery-modal>
# <dealer-inspire-contact-modal apigee-host="https://api.cars.com" conversations-host="https://prod.api.conversations.dealerinspire.com" dealer-inspire-api-key="491NESWmW9LFVNV3gFmTdUvLFc2gPvUF" sms-analytics-url="/dealer-inspire-service/cars/sms/analytics">
# </dealer-inspire-contact-modal>
# <div class="cars-shop-srp-block" ng-non-bindable="">
# </div>
# <footer ng-non-bindable="">
#  <cars-convert-web-to-app-banner>
#  </cars-convert-web-to-app-banner>
#  <footer>
#   <div class="footer">
#    <div class="container col-group">
#     <div class="col-mb-12 col-2 col-dt-3">
#      <input id="footer-our-company" type="checkbox"/>
#      <label for="footer-our-company">
#       Our Company
#       <div class="cui-icon">
#        <svg class="icon-image">
#         <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#chevron" xmlns:xlink="http://www.w3.org/1999/xlink">
#         </use>
#        </svg>
#       </div>
#      </label>
#      <ul class="toggle-footer">
#       <li class="footer-item">
#        <a href="/about/" target="_self">
#         About Cars.com
#        </a>
#       </li>
#       <li class="footer-item">
#        <a data-customlink="pv2" data-linkname="Investor Relations" href="http://investor.cars.com/overview/default.aspx" target="_self">
#         Investor Relations
#        </a>
#       </li>
#       <li class="footer-item">
#        <a href="/contact/" target="_self">
#         Contact Cars.com
#        </a>
#       </li>
#       <li class="footer-item">
#        <a href="/mobile/" target="_self">
#         Mobile Apps
#        </a>
#       </li>
#       <li class="footer-item">
#        <a href="/sitemap/" target="_self">
#         Site Map
#        </a>
#       </li>
#       <li class="footer-item">
#        <a href="/careers/" target="_self">
#         Careers
#        </a>
#       </li>
#       <li class="footer-item">
#        <a href="/fraud-awareness/" target="_self">
#         Fraud Awareness
#        </a>
#       </li>
#       <li class="footer-item">
#        <a data-linkname="footer-licensing-reprints" href="https://wrightsmedia.com/sites/cars/" target="_self">
#         Licensing &amp; Reprints
#        </a>
#       </li>
#      </ul>
#     </div>
#     <nav>
#      <div class="col-mb-12 col-2 col-dt-3">
#       <input id="buying-and-selling" type="checkbox"/>
#       <label for="buying-and-selling">
#        Buying &amp; Selling
#        <div class="cui-icon">
#         <svg class="icon-image">
#          <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#chevron" xmlns:xlink="http://www.w3.org/1999/xlink">
#          </use>
#         </svg>
#        </div>
#       </label>
#       <ul class="toggle-footer">
#        <li class="footer-item">
#         <a href="/shopping/" target="_self">
#          Find a Car
#         </a>
#        </li>
#        <li class="footer-item">
#         <a href="/cpo/" target="_self">
#          Certified Pre-Owned
#         </a>
#        </li>
#        <li class="footer-item">
#         <a href="/sell/" target="_self">
#          Sell Your Car
#         </a>
#        </li>
#        <li class="footer-item">
#         <a href="/sell/book-value/" target="_self">
#          Car Book Values
#         </a>
#        </li>
#        <li class="footer-item">
#         <a href="/dealers/buy/" target="_self">
#          Car Dealers
#         </a>
#        </li>
#        <li class="footer-item">
#         <a href="/price/" target="_self">
#          Compare Car Prices
#         </a>
#        </li>
#        <li class="footer-item">
#         <a href="/sitemap/city-listings/" target="_self">
#          Listings by City
#         </a>
#        </li>
#       </ul>
#      </div>
#     </nav>
#     <div class="col-mb-12 col-2 col-dt-2">
#      <input id="footer-partner" type="checkbox"/>
#      <label for="footer-partner">
#       Our Partners
#       <div class="cui-icon">
#        <svg class="icon-image">
#         <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#chevron" xmlns:xlink="http://www.w3.org/1999/xlink">
#         </use>
#        </svg>
#       </div>
#      </label>
#      <ul class="toggle-footer partner">
#       <li class="footer-item">
#        <a href="https://www.auto.com/" target="_self">
#         Auto.com
#        </a>
#       </li>
#       <li class="footer-item">
#        <a href="http://www.newcars.com/" target="_self">
#         NewCars.com
#        </a>
#       </li>
#       <li class="footer-item">
#        <a href="https://www.repairpal.com/" target="_self">
#         RepairPal.com
#        </a>
#       </li>
#       <li>
#        <cars-cobrand-footer>
#        </cars-cobrand-footer>
#       </li>
#      </ul>
#     </div>
#     <div class="col-mb-12 col-4 col-dt-4 social-media">
#      <div class="social-buttons white">
#       <a href="https://twitter.com/carsdotcom/" target="_self">
#        <div class="cui-icon twitter">
#         <svg class="icon-image">
#          <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#twitter" xmlns:xlink="http://www.w3.org/1999/xlink">
#          </use>
#         </svg>
#        </div>
#       </a>
#       <a href="https://www.facebook.com/CarsDotCom/" target="_self">
#        <div class="cui-icon facebook">
#         <svg class="icon-image">
#          <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#facebook" xmlns:xlink="http://www.w3.org/1999/xlink">
#          </use>
#         </svg>
#        </div>
#       </a>
#       <a href="https://www.youtube.com/user/Carscom/" target="_self">
#        <div class="cui-icon youtube">
#         <svg class="icon-image">
#          <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#youtube" xmlns:xlink="http://www.w3.org/1999/xlink">
#          </use>
#         </svg>
#        </div>
#       </a>
#       <a href="https://www.instagram.com/carsdotcom/?hl=en" target="_self">
#        <div class="cui-icon instagram">
#         <svg class="icon-image">
#          <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#instagram" xmlns:xlink="http://www.w3.org/1999/xlink">
#          </use>
#         </svg>
#        </div>
#       </a>
#       <a href="https://www.linkedin.com/company/cars-com" target="_self">
#        <div class="cui-icon linkedin">
#         <svg class="icon-image">
#          <use xlink:href="/static/www/fb628e116171/app/images/srp-svg/symbolMap.svg#linkedin" xmlns:xlink="http://www.w3.org/1999/xlink">
#          </use>
#         </svg>
#        </div>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="copyrights">
#     <div class="container col-group prev">
#      <div class="col-mb-11 col-7 col-dt-8">
#       <a href="/about/terms/" target="_self">
#        Terms of Service
#       </a>
#       <a href="/about/privacy/" target="_self">
#        Privacy Statement
#       </a>
#       <a href="/about/ad-choices/" target="_self">
#        Ad Choices
#       </a>
#       <span id="signal-link-container-footer">
#       </span>
#      </div>
#      <div class="col-mb-12 col-12 col-dt-4 footer-text" id="footer-copyright">
#       © 2019 Cars.com
#                     All rights reserved.
#      </div>
#     </div>
#    </div>
#   </div>
#  </footer>
#  <div id="cars-omniture-tracking-pixel">
#  </div>
#  <cars-ad-mediator>
#  </cars-ad-mediator>
#  <script>
#   var userSummary;
#     var userSummaryValue = localStorage.getItem("cars.userSummary");
#     if (userSummaryValue) {
#         try {
#             userSummary = JSON.parse(userSummaryValue);
#         } catch(e) {}
#         }
#
#     if (userSummary && userSummary.email) {
#         _etmc.push(["setOrgId", "carscomconsumer"]);
#         _etmc.push(["setUserInfo", {"email": userSummary.email}]);
#         _etmc.push(["trackPageView"]);
#         }
#  </script>
# </footer>
# <script async="" src="//www.googletagservices.com/tag/js/gpt.js">
# </script>
# <script async="" src="//www.cars.com/cldstatic/ads/prebid/1.34.0/prebid.js">
# </script>
# <script>
#  var pbjs = pbjs || {};
#             pbjs.que = pbjs.que || [];
# </script>
# <script>
#  if (window.performance && window.performance.mark) {
#         window.performance.mark("beforeFooter");
#     }
#
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#         googletag.cmd.push(function () {
#             googletag.pubads().disableInitialLoad();
#             googletag.pubads().enableAsyncRendering();
#                 googletag.pubads().enableLazyLoad({
#                     fetchMarginPercent: 400,
#                     renderMarginPercent: 100,
#                     mobileScaling: 2
#                 });
#         });
#
#         window.CARS = window.CARS || {};
#         window.CARS.angularIsBootstrappedInDomLoaded = true;
#
#     if (window.performance && window.performance.mark) {
#         window.performance.mark("afterFooter");
#     }
# </script>
# <script>
#  if (typeof window.callSourceAnimationEnd === "function") {
#         window.callSourceAnimationEnd();
#     }
# </script>
# <link href="/static/www/fb628e116171/app/bundles/srp2.css" rel="stylesheet" type="text/css">
# </link>

# %% [markdown]
# Now, we can see where the data we want is located

# %%
# We are going to loop over all eleven pages and append each entry to a new list

l = []

for i in pages:
    page = requests.get(i)
    soup = BeautifulSoup(page.text, 'html.parser')
    x = soup.find_all(class_ = 'listing-row__phone obscure')
    for i in x:
        l.append(i)

# %%
# Let's see if the results look okay

l[:5]
# Out:
# [<div class="listing-row__phone obscure">
#  <div class="fake-number"> (<span></span>) <span></span>-<span></span></div>
#                                              (301) 945-9727
#                                          </div>,
#  <div class="listing-row__phone obscure" data-customlink="page-state" data-linkname="dealer-phone-srp" data-phone-click=' {"listingId":776385613,"mkId":20015,"mkNm":"Ford","mdId":21712,"mdNm":"Mustang","trimId":35423,"trimName":"V6 Premium","modelYearId":51683,"modelYear":2014,"stkTyp":"Used","state":"MD","zipcode":"20814","phone":"3019459727","sellerId":467378,"apigeeHost":"https://api.cars.com","shadowSettingsProxy":"/consumer-shadow-settings/","srpAPIKey":"Fi1DINVeB0SQhnD1FvtAfUX0KuwHF8Al","bodystyleName":"Coupe","price":14850,"dealerName":"Kensington Auto Sales Inc","customerId":188866,"stockType":"Used","cpo":false}'>
#  <div class="fake-number"> (<span></span>) <span></span>-<span></span></div>
#                                              (301) 945-9727
#                                          </div>,
#  <div class="listing-row__phone obscure">
#  <div class="fake-number"> (<span></span>) <span></span>-<span></span></div>
#                                              (877) 887-7910
#                                          </div>,
#  <div class="listing-row__phone obscure" data-customlink="page-state" data-linkname="dealer-phone-srp" data-phone-click=' {"listingId":773415394,"mkId":20015,"mkNm":"Ford","mdId":21712,"mdNm":"Mustang","trimId":29632,"trimName":"","modelYearId":35797618,"modelYear":2018,"stkTyp":"Used","state":"VA","zipcode":"20814","phone":"8778877910","sellerId":56915476,"apigeeHost":"https://api.cars.com","shadowSettingsProxy":"/consumer-shadow-settings/","srpAPIKey":"Fi1DINVeB0SQhnD1FvtAfUX0KuwHF8Al","bodystyleName":"Coupe","price":23497,"dealerName":"Ourisman Honda of Tysons Corner","customerId":5386115,"stockType":"Used","cpo":false}'>
#  <div class="fake-number"> (<span></span>) <span></span>-<span></span></div>
#                                              (877) 887-7910
#                                          </div>,
#  <div class="listing-row__phone obscure">
#  <div class="fake-number"> (<span></span>) <span></span>-<span></span></div>
#                                              (301) 658-7701
#                                          </div>]

# %% [markdown]
# There seems to be unwanted information between every data entry.
# We can get rid of every other item

# %%
all_cars = l[1::2]

# %% [markdown]
# Now, transform the list into pandas data frame so it can be cleaned

# %%
import pandas as pd
import numpy as np

# %%
df = pd.Series(all_cars)

# %%
data = df.to_frame('text')

# %%
# Check the data just in case
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 1 columns):
# text    220 non-null object
# dtypes: object(1)
# memory usage: 1.8+ KB

# %% [markdown]
# We can start cleaning the data

# %%
# Change the data from an Object to a String so we can manupulate it easily
data['text2'] = data['text'].astype('str')

# %%
data['text2'][1]
# Out:
# '<div class="listing-row__phone obscure" data-customlink="page-state" data-linkname="dealer-phone-srp" data-phone-click=\' {"listingId":773415394,"mkId":20015,"mkNm":"Ford","mdId":21712,"mdNm":"Mustang","trimId":29632,"trimName":"","modelYearId":35797618,"modelYear":2018,"stkTyp":"Used","state":"VA","zipcode":"20814","phone":"8778877910","sellerId":56915476,"apigeeHost":"https://api.cars.com","shadowSettingsProxy":"/consumer-shadow-settings/","srpAPIKey":"Fi1DINVeB0SQhnD1FvtAfUX0KuwHF8Al","bodystyleName":"Coupe","price":23497,"dealerName":"Ourisman Honda of Tysons Corner","customerId":5386115,"stockType":"Used","cpo":false}\'>\n<div class="fake-number"> (<span></span>) <span></span>-<span></span></div>\n                                            (877) 887-7910\n                                        </div>'

# %%
# We are only interested in the text between the brackets
data['text3'] = data['text2'].apply(lambda st: st[st.find("{")+1:st.find("}")])

# %%
data['text3'].head(15)
# Out:
# 0     "listingId":776385613,"mkId":20015,"mkNm":"For...
# 1     "listingId":773415394,"mkId":20015,"mkNm":"For...
# 2     "listingId":776082126,"mkId":20015,"mkNm":"For...
# 3     "listingId":773039496,"mkId":20015,"mkNm":"For...
# 4     "listingId":776639811,"mkId":20015,"mkNm":"For...
# 5     "listingId":769175771,"mkId":20015,"mkNm":"For...
# 6     "listingId":772129975,"mkId":20015,"mkNm":"For...
# 7     "listingId":771098935,"mkId":20015,"mkNm":"For...
# 8     "listingId":770461485,"mkId":20015,"mkNm":"For...
# 9     "listingId":776811460,"mkId":20015,"mkNm":"For...
# 10    &quot;listingId&quot;:775766626,&quot;mkId&quo...
# 11    "listingId":777053169,"mkId":20015,"mkNm":"For...
# 12    "listingId":773040943,"mkId":20015,"mkNm":"For...
# 13    "listingId":775135983,"mkId":20015,"mkNm":"For...
# 14    "listingId":776332904,"mkId":20015,"mkNm":"For...
# Name: text3, dtype: object

# %% [markdown]
# Not all entries are the same, this can be changed

# %%
data['text3'] = data['text3'].str.replace('&quot;', '"')

# %%
data['text3'].head(15)
# Out:
# 0     "listingId":776385613,"mkId":20015,"mkNm":"For...
# 1     "listingId":773415394,"mkId":20015,"mkNm":"For...
# 2     "listingId":776082126,"mkId":20015,"mkNm":"For...
# 3     "listingId":773039496,"mkId":20015,"mkNm":"For...
# 4     "listingId":776639811,"mkId":20015,"mkNm":"For...
# 5     "listingId":769175771,"mkId":20015,"mkNm":"For...
# 6     "listingId":772129975,"mkId":20015,"mkNm":"For...
# 7     "listingId":771098935,"mkId":20015,"mkNm":"For...
# 8     "listingId":770461485,"mkId":20015,"mkNm":"For...
# 9     "listingId":776811460,"mkId":20015,"mkNm":"For...
# 10    "listingId":775766626,"mkId":20015,"mkNm":"For...
# 11    "listingId":777053169,"mkId":20015,"mkNm":"For...
# 12    "listingId":773040943,"mkId":20015,"mkNm":"For...
# 13    "listingId":775135983,"mkId":20015,"mkNm":"For...
# 14    "listingId":776332904,"mkId":20015,"mkNm":"For...
# Name: text3, dtype: object

# %% [markdown]
# It seems to be correct now
#
# Let's split the text into multiple new columns for each category

# %%
splitt = data['text3'].str.split(",", expand = True)

# %%
data['Make'] = splitt[2].str.split(':').str[1]
data['Model'] = splitt[4].str.split(':').str[1]
data['Trim'] = splitt[6].str.split(':').str[1]
data['Year'] = splitt[8].str.split(':').str[1]
data['Condition'] = splitt[9].str.split(':').str[1]
data['State'] = splitt[10].str.split(':').str[1]
data['ZipCode'] = splitt[11].str.split(':').str[1]
data['Price'] = splitt[18].str.split(':').str[1]
data['Dealer'] = splitt[19].str.split(':').str[1]

# %%
data = data[['Make', 'Model', 'Trim', 'Year', 'Condition',
       'State', 'ZipCode', 'Price', 'Dealer']]

# %% [markdown]
# Check on the data

# %%
data.head()
# Out:
#      Make      Model                Trim  Year Condition State  ZipCode  \
# 0  "Ford"  "Mustang"        "V6 Premium"  2014    "Used"  "MD"  "20814"
# 1  "Ford"  "Mustang"                  ""  2018    "Used"  "VA"  "20814"
# 2  "Ford"  "Mustang"                "GT"  2017    "Used"  "MD"  "20814"
# 3  "Ford"  "Mustang"                "GT"  2018    "Used"  "MD"  "20814"
# 4  "Ford"  "Mustang"  "EcoBoost Premium"  2016    "Used"  "MD"  "20814"
#
#    Price                                 Dealer
# 0  14850            "Kensington Auto Sales Inc"
# 1  23497      "Ourisman Honda of Tysons Corner"
# 2  29970  "DARCARS Volkswagen of Silver Spring"
# 3  31500  "Sheehy Ford Lincoln of Gaithersburg"
# 4  19900                         "Academy Ford"

# %%
# Get rid of the quotation marks
data['Make'] = data['Make'].astype('str').str.replace('"', '')
data['Model'] = data['Model'].astype('str').str.replace('"', '')
data['Trim'] = data['Trim'].astype('str').str.replace('"', '')
data['Condition'] = data['Condition'].astype('str').str.replace('"', '')
data['State'] = data['State'].astype('str').str.replace('"', '')
data['ZipCode'] = data['ZipCode'].astype('str').str.replace('"', '')
data['Dealer'] = data['Dealer'].astype('str').str.replace('"', '')

# %%
data.head()
# Out:
#    Make    Model              Trim  Year Condition State ZipCode  Price  \
# 0  Ford  Mustang        V6 Premium  2014      Used    MD   20814  14850
# 1  Ford  Mustang                    2018      Used    VA   20814  23497
# 2  Ford  Mustang                GT  2017      Used    MD   20814  29970
# 3  Ford  Mustang                GT  2018      Used    MD   20814  31500
# 4  Ford  Mustang  EcoBoost Premium  2016      Used    MD   20814  19900
#
#                                 Dealer
# 0            Kensington Auto Sales Inc
# 1      Ourisman Honda of Tysons Corner
# 2  DARCARS Volkswagen of Silver Spring
# 3  Sheehy Ford Lincoln of Gaithersburg
# 4                         Academy Ford
